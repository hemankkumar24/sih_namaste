# %%
import pandas as pd

# %%
concise_df = pd.read_csv('conciseFinalData.csv')

# %%
concise_df.head()
# Out:
#    Unnamed: 0                                      ICD11_Title ICD11_Code  \
# 0           0         Certain infectious or parasitic diseases        NaN
# 1           1  Gastroenteritis or colitis of infectious origin        NaN
# 2           2                  Bacterial intestinal infections        NaN
# 3           3                                          Cholera       1A00
# 4           4         Intestinal infection due to other Vibrio       1A01
#
#    ICD11_DepthInKind  ICD11_IsResidual  Ayurveda_NAMC_ID Ayurveda_NAMC_CODE  \
# 0                  1             False                11            AAA-2.4
# 1                  1             False               450        SR81 (CB-1)
# 2                  2             False               524             EB-2.8
# 3                  1             False               763    SP58(EC-3.10.2)
# 4                  1             False               632       SM72(EB-9.4)
#
#       Ayurveda_NAMC_term Ayurveda_NAMC_term_diacritical  \
# ...

# %%
concise_df.columns
# Out:
# Index(['Unnamed: 0', 'ICD11_Title', 'ICD11_Code', 'ICD11_DepthInKind',
#        'ICD11_IsResidual', 'Ayurveda_NAMC_ID', 'Ayurveda_NAMC_CODE',
#        'Ayurveda_NAMC_term', 'Ayurveda_NAMC_term_diacritical',
#        'Ayurveda_NAMC_term_DEVANAGARI', 'Ayurveda_Long_definition',
#        'Siddha_NAMC_ID', 'Siddha_NAMC_CODE', 'Siddha_NAMC_TERM',
#        'Siddha_Tamil_term', 'Siddha_Long_definition', 'Unani_NUMC_CODE',
#        'Unani_Arabic_term', 'Unani_NUMC_TERM', 'Unani_Short_definition',
#        'Unani_Long_definition', 'Ayurveda_Similarity', 'Siddha_Similarity',
#        'Unani_Similarity'],
#       dtype='object')

# %%
query_df = concise_df[['ICD11_Code', 'Ayurveda_NAMC_CODE', 'Siddha_NAMC_CODE', 'Unani_NUMC_CODE', 'ICD11_Title']]

# %%
query_df.head()
# Out:
#   ICD11_Code Ayurveda_NAMC_CODE Siddha_NAMC_CODE Unani_NUMC_CODE  \
# 0        NaN            AAA-2.4          WAB1.12             P-7
# 1        NaN        SR81 (CB-1)           ECB1.1         F-92.18
# 2        NaN             EB-2.8           TDB1.7         F-92.10
# 3       1A00    SP58(EC-3.10.2)           AEC1.1          F-92.5
# 4       1A01       SM72(EB-9.4)           WAB1.4          F-92.5
#
#                                        ICD11_Title
# 0         Certain infectious or parasitic diseases
# 1  Gastroenteritis or colitis of infectious origin
# 2                  Bacterial intestinal infections
# 3                                          Cholera
# 4         Intestinal infection due to other Vibrio

# %%
query_df.to_csv("query_database.csv")
